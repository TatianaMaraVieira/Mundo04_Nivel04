# %% [markdown]
# ![logo_estacio3.png](data:image/png;base64,...)

# %% [markdown]
# > **Campus:** Jacarepagua - Rio de Janeiro/RJ
# >
# >  **GRADUAÇÃO DESENVOLVIMENTO FULL STACK**
# >
# > **Disciplina:** Nível 4: Tirando Proveito da Nuvem Para Projetos de Software
# >
# > **Turma:** 2022.03 - Mundo 4
# >
# > **Aluna:** Tatiana M Vieira
# >
# > **Matrícula:** 202304161828
# >
# > [![GitHub](https://img.shields.io/badge/GitHub-100000?style=for-the-badge&logo=github&logoColor=white)](https://github.com/TatianaMaraVieira)

# %% [markdown]
# >### **Objetivos da prática**
# >
# >* Instalação do Android Studio e do emulador;
# >
# >* Criar um app para Wear OS;
# >
# >* Executar um app no emulador;
# >
# >* Fazer capturas de telas no Android Studio;
# >
# >* Fazer capturas de telas com app complementar.
# >

# %% [markdown]
# >### **Microatividade 1: Criar uma Máquina Virtual (VM) no Azure**
# >
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >### **Microatividade 2: Configurar Regras de Rede e Grupos de Segurança no Azure**
# >
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >### **Microatividade 3: Criar um banco de dados SQL do Azure**
# >
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >### **Microatividade 4: Conecta-se ao seu banco de dados**
# >
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >### **Microatividade 5: CRUD em um Banco de Dados SQL do Azure**
# >
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >### **Missão Prática | Tirando proveito da nuvem para projetos de software**
# >
# >**Objetivos do Projeto:**
# >
# >- Desenvolver um banco de dados robusto e seguro no Azure SQL.
# >- Garantir que o BD possa escalar conforme a empresa cresce.
# >- Facilitar a integração com outras plataformas e serviços.
# >
# >O projeto visa transformar radicalmente a maneira como a *LogiMove Transportes*
# opera, aumentando a eficiência, reduzindo atrasos e melhorando a satisfação do
# cliente. A adoção de uma solução baseada em Azure SQL é um passo significativo em direção à digitalização e modernização das operações da empresa.
# >
# >![image.png](data:image/png;base64,...)
# >
# ![image.png](data:image/png;base64,...)
# >
# ![image.png](data:image/png;base64,...)
# >
#
# ![image.png](data:image/png;base64,...)
# >
# ![image.png](data:image/png;base64,...)
# >
# ![image.png](data:image/png;base64,...)
# >
